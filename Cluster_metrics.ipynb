# job
# john
# know
# laboratory
# land
# letters
# m
# magic
# making
# management
# manuscripts
# mary
# may
# meaning
# memoir
# mississippi
# mother
# motor
# music
# needs
# negro
# news
# non
# north
# official
# ordinance
# organization
# origins
# others
# palestine
# part
# patterns
# philosophical
# poetical
# poets
# political
# portrait
# power
# practical
# practice
# primer
# processes
# processing
# properties
# questions
# railway
# re
# reader
# recent
# recipes
# research
# resources
# revision
# roman
# russia
# sculpture
# section
# selected
# service
# seven
# soul
# south
# statistics
# stone
# story
# strategy
# street
# surgery
# sustainable
# tales
# technical
# techniques
# ten
# testament
# theology
# theories
# traffic
# transfer
# treasury
# trees
# u
# united
# verse
# violence
# wars
# within
# workers
# 1850
# 1960
# 4
# address
# advanced
# africa
# african
# aid
# almanack
# among
# anthropology
# anti
# arab
# arithmetic
# asia
# asian
# assessment
# astronomy
# behavior
# bible
# bibliography
# blue
# body
# boy
# causes
# cell
# century
# charles
# chemical
# chemistry
# child
# columbia
# commercial
# companion
# compensation
# comprehensive
# concerning
# conduct
# conflict
# contract
# correspondence
# countries
# county
# cultural
# d
# data
# david
# day
# death
# delivered
# department
# description
# descriptive
# disease
# doctrine
# eastern
# easy
# era
# etc
# europe
# experience
# factors
# families
# february
# fiction
# five
# foreign
# fourth
# francis
# french
# game
# geography
# geometry
# glass
# god
# governance
# grand
# guide
# hearing
# high
# historical
# history
# hospital
# ideas
# implementation
# indians
# information
# integration
# interest
# introduction
# issues
# james
# jewish
# june
# l
# lady
# latin
# louis
# love
# low
# maine
# managing
# marine
# marriage
# master
# materials
# measurement
# media
# medicine
# mind
# mission
# models
# museum
# national
# nations
# novel
# november
# open
# paper
# park
# past
# pennsylvania
# perspective
# peter
# poems
# policy
# poor
# preached
# prices
# program
# projects
# railroad
# reading
# regulation
# revenue
# revised
# right
# river
# robert
# safety
# sales
# science
# secondary
# selection
# several
# sexual
# short
# sir
# sketches
# spanish
# species
# speech
# star
# states
# status
# subject
# sun
# survey
# symposium
# systems
# taxation
# television
# tennessee
# test
# thoughts
# together
# towards
# town
# trade
# tradition
# training
# two
# understanding
# upon
# using
# values
# village
# welfare
# wild
# word
# writing

# %%
data_dir = "ngrams/timeseries_data/"
file_name = data_dir + "books_per_year"
bookcount = pd.read_csv(file_name, delim_whitespace = True, header = None)
bookcount.columns = ['_year', 'total_books']
bookcount.sort(columns = '_year', inplace = True)
bookcount['_year'] = bookcount['_year'].apply(int)
bookcount['total_books'] = bookcount['total_books'].apply(int)
bookcount = bookcount.set_index(bookcount['_year'])
bookcount = bookcount[bookcount['_year'] >= 1800]
bookcount = bookcount[bookcount['_year'] <= 2012]
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas-0.10.1-py2.7-linux-i686.egg/pandas/core/frame.py:3192: FutureWarning: sort/sort_index with inplace=True  will return None from pandas 0.11 onward
#   " from pandas 0.11 onward", FutureWarning)

# %%
bookcount.head()
# Out:
#        _year  total_books
# _year
# 1800    1800         3495
# 1801    1801         1950
# 1802    1802         2112
# 1803    1803         2236
# 1804    1804         2259

# %%
normalized_by_total_books = allwords.astype(float).div(bookcount['total_books'], axis = 0)
normalized_by_total_books.fillna(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213 entries, 1800.0 to 2012
# Columns: 1312 entries, 12 to writing
# dtypes: float64(1312)

# %% [markdown]
# Normalize every word timeseries to be in range [0;1]

# %%
dmin, dmax = normalized_by_total_books.min(axis=0), normalized_by_total_books.max(axis=0)
normalized_by_word = (normalized_by_total_books - dmin) / (dmax - dmin)

# %%
normalized_by_word = normalized_by_word.fillna(0)

# %%
def plot_regress_line(word):
    from scipy import stats
    #slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
    united = stats.linregress(normalized_by_word[word].index, normalized_by_word[word])
    regress = map(lambda x: united[0]*x + united[1], range(1800, 2013))
    regser = Series(regress, index = range(1800, 2013))
    #normalized_by_word[word].plot()
    #normalized_by_word[word].plot()
    substracted = (normalized_by_word[word]-regser)
    return substracted

# %%
s = plot_regress_line('war')

# %%
s
# Out:
# _year
# 1800    -0.013641
# 1801    -0.021232
# 1802    -0.079812
# 1803    -0.000436
# 1804    -0.055926
# 1805    -0.004829
# 1806     0.013321
# 1807     0.001687
# 1808     0.021087
# 1809    -0.009849
# 1810    -0.041607
# 1811    -0.015927
# 1812     0.321755
# 1813     0.075223
# 1814     0.060929
# ...
# 1998.0   -0.027714
# 1999.0   -0.029107
# 2000.0   -0.022671
# 2001.0   -0.020838
# 2002.0   -0.019147
# 2003.0   -0.010807
# 2004.0   -0.006794
# 2005.0   -0.016555
# 2006.0   -0.035494
# 2007.0   -0.045304
# 2008.0   -0.019045
# 2009.0   -0.018411
# 2010.0   -0.022542
# 2011.0   -0.019027
# 2012     -0.136460
# Length: 213

# %%
normalized_by_word['united'].plot()

# %%
import pickle
with open('normalized.df', 'w') as f:
    f.write(pickle.dumps(normalized_by_total_books))
with open('normalized_by_word.df', 'w') as f:
    f.write(pickle.dumps(normalized_by_word))

# %%
def skewness(series):
    m = series.mean()
    s = series.std()
    diff = series.sub(m)
    cubed = diff.apply(lambda x: x**3)
    return (cubed.sum())/(len(series)*s**3)

# %%
def kurtosis(series):
    m = series.mean()
    s = series.std()
    diff = series.sub(m)
    cubed = diff.apply(lambda x: x**4)
    return ((cubed.sum())/(len(series)*s**4))-3

# %%
from scipy import stats
agg_df = {'Word': [], 'Mean': [], 'Variance': [], 'Skewness': [], 'Kurtosis': [], 'Reg_Slope': [], 'Reg_Error': [], 'r': [], 'p_value': []}

for word in normalized_by_word.columns:
    agg_df['Word'].append(word)
    agg_df['Mean'].append(normalized_by_word[word].mean())
    agg_df['Variance'].append(normalized_by_word[word].var())
    agg_df['Skewness'].append(skewness(normalized_by_word[word]))
    agg_df['Kurtosis'].append(kurtosis(normalized_by_word[word]))
    slope, intercept, r_value, p_value, std_err = stats.linregress(normalized_by_word[word].index, normalized_by_word[word])
    agg_df['Reg_Slope'].append(slope)
    agg_df['Reg_Error'].append(std_err)
    agg_df['r'].append(r_value)
    agg_df['p_value'].append(p_value)

# %%
metrics = DataFrame(agg_df)

# %%
normalized_by_word['problems'].hist(bins = 100)

# %%
metrics['Reg_Error'].hist(bins = 100)

# %%
normalized_by_word['problems'].plot()

# %%
metrics.sort(columns = ['Reg_Error'], ascending = True)[:50]
# Out:
#         Kurtosis      Mean  Reg_Error  Reg_Slope   Skewness  Variance           Word  \
# 367   105.678407  0.055277   0.000072  -0.000669   8.914287  0.005875         george
# 314   189.772353  0.011940   0.000077  -0.000137  13.611161  0.004820           1800
# 306   118.000622  0.044008   0.000078  -0.000453   9.803312  0.005712     washington
# 1194   42.216117  0.079857   0.000080  -0.000978   5.042872  0.008801       february
# 706   149.315409  0.027884   0.000081  -0.000097  11.494057  0.005254        lincoln
# 478   144.275858  0.015212   0.000082   0.000183  11.406086  0.005508           1939
# 909   133.114248  0.032344   0.000083  -0.000096  10.626632  0.005512         oregon
# 277    97.943217  0.045508   0.000084  -0.000422   8.764893  0.006292          queen
# 1131  139.694642  0.017102   0.000084  -0.000039  11.385455  0.005634           1850
# 431   115.159486  0.054745   0.000084  -0.000042   9.453542  0.005637         reform
# 973   133.186691  0.011646   0.000084   0.000178  11.055638  0.005840           1961
# 797   135.403563  0.011186   0.000085   0.000140  11.194914  0.005799           1948
# 1     121.014266  0.018309   0.000085   0.000268  10.403497  0.006070           1945
# 545     8.663832  0.154108   0.000085  -0.001696   2.266409  0.016738        general
# 971   128.241053  0.013459   0.000085   0.000175  10.833914  0.005952           1947
# 169   121.403563  0.022519   0.000086   0.000173  10.400618  0.006001           1900
# 796   119.413279  0.015444   0.000087   0.000183  10.324064  0.006130           1940
# 1132  116.388799  0.014698   0.000087   0.000234  10.217909  0.006256           1960
# 626   119.996286  0.015352   0.000087   0.000147  10.421428  0.006149           1930
# 801    37.260770  0.084644   0.000088  -0.000908   4.692703  0.009266      alexander
# 481    97.548675  0.018740   0.000088   0.000418   9.207885  0.006802           2000
# 2     117.225840  0.011627   0.000088   0.000197  10.395715  0.006346           1967
# 477   114.813080  0.016727   0.000088   0.000135  10.194689  0.006307           1920
# 316   107.834403  0.013958   0.000090   0.000229   9.908326  0.006625           1965
# 972   102.850050  0.016938   0.000090   0.000237   9.532313  0.006671           1950
# 970    93.602299  0.025278   0.000092   0.000208   8.929786  0.006916           1914
# 3      95.945594  0.016645   0.000092   0.000297   9.290227  0.007102           1970
# 394    32.693130  0.069617   0.000093  -0.000989   4.614939  0.010682        majesty
# 517    66.965109  0.040436   0.000093   0.000463   7.083531  0.007780        defense
# 536    -0.602984  0.283922   0.000095  -0.003089   0.465230  0.043470          first
# 330    52.939366  0.041349   0.000095   0.000618   6.168577  0.008701       bulletin
# 602    21.781970  0.076673   0.000096  -0.001188   3.758990  0.012719         senate
# 890     3.352233  0.198140   0.000096  -0.002094   1.486393  0.024017  massachusetts
# 1283   60.250972  0.074896   0.000097  -0.000014   6.193892  0.007471           star
# 662   9.931248e-29 -0.666527
# 806   1.990135e-28 -0.663782

# %%
metrics = metrics.set_index('Word')

# %%
metrics['r_sq'] = metrics['r'].apply(lambda x: x**2)

# %%
metrics_norm = (metrics - metrics.min())/(metrics.max() - metrics.min())

# %%
metrics_norm.sort(columns = ['Mean'], ascending= True)[:30]
# Out:
#             Kurtosis      Mean  Reg_Error  Reg_Slope  Skewness  Variance  \
# Word
# 1948        0.715914  0.000000   0.057050   0.475374  0.829702  0.008708
# 1967        0.620933  0.000798   0.072940   0.481601  0.773375  0.013577
# 1961        0.704331  0.000833   0.056862   0.479586  0.819886  0.009072
# 1800        1.000000  0.001367   0.022161   0.444918  1.000000  0.000000
# 1947        0.678489  0.004119   0.060846   0.479208  0.804259  0.010073
# 1965        0.571861  0.005024   0.080311   0.485178  0.739023  0.016062
# 1960        0.616559  0.006364   0.067943   0.485710  0.760843  0.012776
# 1939        0.762274  0.007296   0.045112   0.480115  0.844586  0.006118
# 1930        0.635409  0.007549   0.068569   0.476184  0.775187  0.011824
# 1940        0.632363  0.007716   0.066438   0.480097  0.768325  0.011653
# 1970        0.509740  0.009893   0.091184   0.492596  0.695460  0.020305
# 1920        0.608326  0.010042   0.074201   0.474843  0.759206  0.013228
# 1950        0.545817  0.010424   0.081341   0.486045  0.712522  0.016472
# 1850        0.738336  0.010720   0.053744   0.455770  0.843132  0.007237
# 1945        0.640728  0.012909   0.059566   0.489381  0.773923  0.011125
# 2000        0.518117  0.013689   0.070918   0.505917  0.689656  0.017638
# 1990        0.405877  0.014015   0.116005   0.506605  0.621211  0.030654
# 1918        0.446232  0.015841   0.134518   0.476169  0.665020  0.030954
# 1975        0.373393  0.018190   0.149778   0.503493  0.604596  0.040369
# 1900        0.642762  0.020537   0.062571   0.479006  0.773720  0.010506
# 1980        0.343856  0.021096   0.180134   0.510135  0.582558  0.052202
# 1914        0.497496  0.025538   0.090683   0.482877  0.670056  0.018650
# lincoln     0.788606  0.030260   0.039377   0.449386  0.850786  0.003861
# oregon      0.703952  0.038343   0.048516   0.449505  0.789650  0.006155
# kansas      0.306823  0.052127   0.184670   0.448903  0.547274  0.047053
# defense     0.358313  0.053007   0.097427   0.510795  0.539931  0.026346
# bulletin    0.285026  0.054662   0.106151   0.527799  0.475445  0.034537
# washington  0.624981  0.059480   0.028954   0.410232  0.731622  0.007940
# queen       0.520178  0.062198   0.053328   0.413701  0.658434  0.013095
# reform      0.610136  0.078938   0.053840   0.455407  0.706970  0.007271
#
#                  p_value         r      r_sq
# Word
# 1948        1.006782e-01  0.573064  0.014710
# 1967        2.674139e-02  0.594334  0.026539
# 1961        3.645237e-02  0.589771  0.023709
# 1800        7.707082e-02  0.444384  0.017024
# 1947        4.225580e-02  0.587518  0.022371
# 1965        1.130067e-02  0.606053  0.034536
# 1960        7.705298e-03  0.610879  0.038135
# 1939        2.681739e-02  0.594293  0.026513
# 1930        9.321192e-02  0.574445  0.015373
# 1940        3.615888e-02  0.589893  0.023783
# 1970        1.451314e-03  0.629837  0.053999
# 1920        1.290302e-01  0.568464  0.012608
# 1950        8.973147e-03  0.608985  0.036701
# 1850        6.577190e-01  0.493774  0.001143
# 1945        1.920433e-03  0.626859  0.051325
# 2000        3.331849e-06  0.682017  0.111876
# 1990        2.014473e-05  0.668481  0.094859
# 1918        1.497663e-01  0.565575  0.011370
# 1975        1.997945e-04  0.649135  0.072974
# 1900        4.539520e-02  0.586406  0.021725
# 1980        5.734304e-05  0.659990  0.084901
# 1914        2.458258e-02  0.595539  0.027313
# lincoln     2.363374e-01  0.466121  0.007734
# oregon      2.532408e-01  0.467675  0.007208
# kansas      3.747223e-01  0.477187  0.004394
# defense     1.449077e-06  0.687888  0.119692
# bulletin    5.995259e-10  0.734246  0.190684
# washington  2.705414e-08  0.308903  0.156480
# queen       1.022320e-06  0.331863  0.122956
# reform      6.293204e-01  0.492297  0.001347

# %%
metrics_norm.ix['1950']
# Out:
# Kurtosis     0.545817
# Mean         0.010424
# Reg_Error    0.081341
# Reg_Slope    0.486045
# Skewness     0.712522
# Variance     0.016472
# p_value      0.008973
# r            0.608985
# r_sq         0.036701
# Name: 1950

# %%
plt.scatter(metrics_norm['p_value'], metrics_norm['Reg_Error'])

# %%
plt.scatter(metrics['r'], metrics['Skewness'])

# %% [markdown]
# K-Means Clustering
# ==================

# %%
from numpy import array
from scipy.cluster.vq import vq, kmeans2, whiten
features  = array(metrics_norm[['Skewness', 'Kurtosis', 'Reg_Slope', 'r']])
#features  = array(metrics_norm[['Skewness', 'Reg_Error', 'Reg_Slope', 'Kurtosis']])
whitened = whiten(features)
book = array((whitened[0],whitened[2]))
centroids, kmeans_labels =kmeans2(whitened, k=5)
# Out:
# /usr/lib/python2.7/dist-packages/scipy/cluster/vq.py:588: UserWarning: One of the clusters is empty. Re-run kmean with a different initialization.
#   warnings.warn("One of the clusters is empty. "

# %%
kmclusters = DataFrame(kmeans_labels, metrics_norm.index, columns = ['KMeans_Cluster'])

# %%
kmeans_df = pd.concat([metrics_norm, kmclusters], axis = 1)

# %%
kmeans_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1312 entries, 12 to writing
# Data columns:
# Kurtosis          1312  non-null values
# Mean              1312  non-null values
# Reg_Error         1312  non-null values
# Reg_Slope         1312  non-null values
# Skewness          1312  non-null values
# Variance          1312  non-null values
# p_value           1312  non-null values
# r                 1312  non-null values
# r_sq              1312  non-null values
# KMeans_Cluster    1312  non-null values
# dtypes: float64(9), int64(1)

# %%
for label, df in kmeans_df.groupby(by = 'KMeans_Cluster'):
    
    fig = plt.figure(int(label), figsize = (10, 10))
    fig.suptitle('Cluster ' +str(label), fontsize=14)
    for word, i in zip(df[20:25].index, range(5)):
        sp = plt.subplot(5,1,i)
        sp.plot(normalized_by_total_books[word].index, normalized_by_total_books[word])

# %%
import scipy.cluster.vq as vq
def cluster_timeseries(features_df, timeseries_df, features = None, k = 5):
    if features:
        whitened = vq.whiten(features_df[features])
    else:
        whitened = vq.whiten(features_df)
    book = array(whitened)
    centroids, kmeans_labels = vq.kmeans2(book, k=5)
    kmclusters = DataFrame(kmeans_labels, features_df.index, columns = ['KMeans_Cluster'])
    kmeans_df = pd.concat([features_df, kmclusters], axis = 1)
    
    return kmeans_df

# %%
def plot_cluster_means(kmeans_df, cluster_column = 'KMeans_Cluster'):
    fig = plt.figure(figsize = (15, 10))
    #c = kmeans_df[cluster_column].value_counts()
    for label, df in kmeans_df.groupby(cluster_column):
        sp = plt.subplot(3, 4, label+1)
        n = len(df)
        sp.text(0.95, 0.95,'c= %s n=%s'%(str(label), str(n)),
                horizontalalignment='right',
                verticalalignment='top',
                transform=sp.transAxes, 
                fontsize = 14)
        words = list(df.index)
        timeseries = normalized_by_total_books[words]
        timeseries.mean(axis = 1).plot()

# %%
def plot_cluster_samples(kmeans_df, cluster_column = 'KMeans_Cluster', n=6):
    c = kmeans_df[cluster_column].value_counts()
    for label, df in kmeans_df.groupby(cluster_column):
        fig = plt.figure(int(label), figsize = (20, 6))
        fig.suptitle('c ='+str(label))
        samples = df[:n]
        for i, word in enumerate(list(samples.index)) :
            #num_rows = (n/3)+1
            num_rows=3
            sp = plt.subplot(3, num_rows, i+1)
            plt.title(word)
            sp.plot(normalized_by_total_books[word].index, np.round(np.array(normalized_by_total_books[word]), decimals = 4))

# %%
df1 = cluster_timeseries(metrics_norm, normalized_by_total_books, features = ['Skewness', 'Kurtosis', 'Reg_Slope', 'Reg_Error'])

# %%
color = {0: 'r', 1: 'y', 2: 'g', 3: 'b', 4: 'c'}
plt.figure(0, figsize = (10, 8))
for glabel, group in df1.groupby('KMeans_Cluster'):
    plt.scatter(group['Skewness'], group['Reg_Slope'], c =color[glabel], label = str(glabel))
plt.legend()

# %%
color = {0: 'r', 1: 'y', 2: 'g', 3: 'b', 4: 'c'}
plt.figure(0, figsize = (10, 8))
for glabel, group in df1.groupby('KMeans_Cluster'):
    plt.scatter(group['Reg_Slope'], group['Reg_Error'], c =color[glabel], label = str(glabel))
plt.legend()

# %%
#plot_cluster_samples(df1)
plot_cluster_means(df1)

# %% [markdown]
# Agglomerative Clustering
# ========================

# %%
from scipy.spatial.distance import pdist, squareform
#This matrix is condensed, to get the redundant matrix call squareform(distMatrix)
distMatrix = pdist(metrics_norm[['Kurtosis', 'Variance', 'Skewness']])

# %%
squareform(distMatrix)[0][1]

# %%
#from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
#linked = linkage(distMatrix, method='complete')
#linked = linkage(metrics_norm[['Kurtosis', 'Variance', 'Skewness']], method='centroid')
#dendrogram(linked,         color_threshold=0.3,            leaf_font_size=6)

# %%
hclusters = DataFrame(fcluster(linked, 1.15470053), metrics_norm.index, columns = ['Hierarchical_Cluster'])

# %%
hier_df = pd.concat([metrics_norm, hclusters], axis = 1)

# %%
for label, df in hier_df.groupby(by = 'Hierarchical_Cluster'):
    print df
